# %% [markdown]
# # Outlier Detection
#
# ### Data Mining Project 2024/25
#
# Authors: Nicola Emmolo, Simone Marzeddu, Jacopo Raffi

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# %%
cyclist = pd.read_csv('../data/cyclists.csv')
races = pd.read_csv('../data/races.csv')

#TODO: remove it when you use cleaned data
#TODO: change the attribute name when you use cleaned data
races['date'] = races['date'].str.split(' ').str[0]
races['date'] = pd.to_datetime(races['date'], format='%Y-%m-%d')

# %% [markdown]
# ## Cyclist Outlier

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='birth_year', data=cyclist)
plt.gca().xaxis.set_major_locator(MultipleLocator(5))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='weight', data=cyclist)
plt.gca().xaxis.set_major_locator(MultipleLocator(3))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='height', data=cyclist)
plt.gca().xaxis.set_major_locator(MultipleLocator(3))
plt.show()

# %% [markdown]
# ## Races Outliers

# %%
tmp_df = tmp_df = pd.DataFrame({
    'race_name': races['name'],
    'year': races['date'].dt.year
}).drop_duplicates()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='year', data=tmp_df)
plt.gca().xaxis.set_major_locator(MultipleLocator(5))
plt.show()

# %%
plt.figure(figsize=(15, 5))
sb.boxenplot(x='length', data=races.drop_duplicates(subset=['_url', 'date']))
#plt.gca().xaxis.set_major_locator(MultipleLocator(5)) TODO: uncomment it when you use cleaned data
plt.show()

# %%
plt.figure(figsize=(15, 5))
sb.boxenplot(x='climb_total', data=races.drop_duplicates(subset=['_url', 'date']))
#plt.gca().xaxis.set_major_locator(MultipleLocator(5)) TODO: uncomment it when you use cleaned data
plt.show()

# %%
tmp_df = tmp_df = pd.DataFrame({
    'race_name': races['name'],
    'year': races['date'].dt.year,
    'startlist_quality': races['startlist_quality']
}).drop_duplicates()

plt.figure(figsize=(15, 5))
sb.boxenplot(x='startlist_quality', data=races.drop_duplicates(subset=['_url', 'date']))
plt.gca().xaxis.set_major_locator(MultipleLocator(100))
plt.show()

# %%
tmp_df = pd.DataFrame({
    'race_name': races['name'],
    'race_url': races['_url'],
    'year': races['date'].dt.year,
    'points': races['points']
}).drop_duplicates()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='points', data=tmp_df)
plt.gca().xaxis.set_major_locator(MultipleLocator(20))
plt.show()

# %%
tmp_df = pd.DataFrame({
    'race_name': races['name'],
    'race_url': races['_url'],
    'year': races['date'].dt.year,
    'uci_points': races['uci_points']
}).drop_duplicates()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='uci_points', data=tmp_df)
plt.gca().xaxis.set_major_locator(MultipleLocator(50))
plt.show()

# %%
tmp_df = pd.DataFrame({
    'race_name': races['name'],
    'race_url': races['_url'],
    'year': races['date'].dt.year,
    'position': races['position']
}).drop_duplicates()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='position', data=tmp_df)
plt.gca().xaxis.set_major_locator(MultipleLocator(20))
plt.show()

# %%
tmp_df = pd.DataFrame({
    'race_name': races['name'],
    'race_url': races['_url'],
    'year': races['date'].dt.year,
    'delta': races['delta']
}).drop_duplicates().dropna()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='delta', data=tmp_df, log_scale=False) #TODO: check with cleaned data
plt.gca().xaxis.set_major_locator(MultipleLocator(5000))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='delta', data=tmp_df, log_scale=True) #TODO: check with cleaned data
plt.show()
# Out:
# /home/jacopo/dm/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4779: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
