# %% [markdown]
# # Outlier Detection
#
# ### Data Mining Project 2024/25
#
# Authors: Nicola Emmolo, Simone Marzeddu, Jacopo Raffi

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# %%
dataset = pd.read_csv('../data/complete_dataset_fe.csv', dtype={'cyclist_team': str})

#TODO: remove it when you use cleaned data
#TODO: change the attribute name when you use cleaned data
dataset['date'] = pd.to_datetime(dataset['date'], format='%Y-%m-%d')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589865 entries, 0 to 589864
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   race_url                      589865 non-null  object
#  1   race_name                     589865 non-null  object
#  2   points                        589388 non-null  float64
#  3   uci_points                    251086 non-null  float64
#  4   length                        589865 non-null  float64
#  5   climb_total                   442820 non-null  float64
#  6   profile                       441671 non-null  float64
#  7   startlist_quality             589865 non-null  int64
#  8   date                          589865 non-null  datetime64[ns]
#  9   position                      589859 non-null  float64
#  10  cyclist_url                   589865 non-null  object
#  11  cyclist_age                   589752 non-null  float64
#  12  mostly_tarmac                 589865 non-null  bool
#  13  cyclist_team                  430704 non-null  object
#  14  delta                         589865 non-null  float64
#  15  cyclist_name                  589865 non-null  object
#  16  birth_year                    589752 non-null  float64
#  17  weight                        478431 non-null  float64
#  18  height                        479746 non-null  float64
#  19  nationality                   589813 non-null  object
#  20  race_season                   589865 non-null  object
#  21  cyclist_bmi                   478121 non-null  float64
#  22  cyclist_age_group             589752 non-null  object
#  23  cyclist_climb_power           351537 non-null  float64
#  24  race_physical_effort          409092 non-null  float64
#  25  race_prestige                 589388 non-null  float64
#  26  cyclist_previous_experience   405848 non-null  float64
#  27  cyclist_days_since_last_race  583770 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(17), int64(1), object(8)
# memory usage: 122.1+ MB

# %% [markdown]
# ## Cyclist Outlier

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='cyclist_age', data=dataset.drop_duplicates(subset=['cyclist_age', 'cyclist_url']))
plt.gca().xaxis.set_major_locator(MultipleLocator(5))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='birth_year', data=dataset.drop_duplicates(subset=['birth_year', 'cyclist_url']))
plt.gca().xaxis.set_major_locator(MultipleLocator(5))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='weight', data=dataset.drop_duplicates(subset=['weight', 'cyclist_url']))
plt.gca().xaxis.set_major_locator(MultipleLocator(3))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='height', data=dataset.drop_duplicates(subset=['height', 'cyclist_url']))
plt.gca().xaxis.set_major_locator(MultipleLocator(3))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='cyclist_bmi', data=dataset.drop_duplicates(subset=['cyclist_bmi', 'cyclist_url']))
plt.gca().xaxis.set_major_locator(MultipleLocator(1))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='cyclist_climb_power', data=dataset.drop_duplicates(subset=['cyclist_climb_power', 'cyclist_url']))
plt.gca().xaxis.set_major_locator(MultipleLocator(0.5)) #TODO: change the value when you use cleaned data
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='cyclist_previous_experience', data=dataset)
plt.gca().xaxis.set_major_locator(MultipleLocator(10))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='cyclist_days_since_last_race', data=dataset)
plt.gca().xaxis.set_major_locator(MultipleLocator(1000))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='cyclist_days_since_last_race', data=dataset, log_scale=True)
plt.show()
# Out:
# /home/jacopo/dm/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4779: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %% [markdown]
# ## Races Outliers

# %%
tmp_df = tmp_df = pd.DataFrame({
    'race_name': dataset['race_name'],
    'year': dataset['date'].dt.year
}).drop_duplicates()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='year', data=tmp_df)
plt.gca().xaxis.set_major_locator(MultipleLocator(5))
plt.show()

# %%
plt.figure(figsize=(15, 5))
sb.boxenplot(x='length', data=dataset.drop_duplicates(subset=['race_url', 'date']))
plt.gca().xaxis.set_major_locator(MultipleLocator(20))
plt.show()

# %%
plt.figure(figsize=(15, 5))
sb.boxenplot(x='climb_total', data=dataset.drop_duplicates(subset=['race_url', 'date']))
plt.gca().xaxis.set_major_locator(MultipleLocator(0.5))
plt.show()

# %%
tmp_df = tmp_df = pd.DataFrame({
    'race_name': dataset['race_name'],
    'year': dataset['date'].dt.year,
    'startlist_quality': dataset['startlist_quality']
}).drop_duplicates()

plt.figure(figsize=(15, 5))
sb.boxenplot(x='startlist_quality', data=dataset.drop_duplicates(subset=['race_url', 'date']))
plt.gca().xaxis.set_major_locator(MultipleLocator(100))
plt.show()

# %%
tmp_df = pd.DataFrame({
    'race_name': dataset['race_name'],
    'race_url': dataset['race_url'],
    'year': dataset['date'].dt.year,
    'points': dataset['points']
}).drop_duplicates()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='points', data=tmp_df)
plt.gca().xaxis.set_major_locator(MultipleLocator(20))
plt.show()

# %%
tmp_df = pd.DataFrame({
    'race_name': dataset['race_name'],
    'race_url': dataset['race_url'],
    'year': dataset['date'].dt.year,
    'uci_points': dataset['uci_points']
}).drop_duplicates()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='uci_points', data=tmp_df)
plt.gca().xaxis.set_major_locator(MultipleLocator(50))
plt.show()

# %%
tmp_df = pd.DataFrame({
    'race_name': dataset['race_name'],
    'race_url': dataset['race_url'],
    'year': dataset['date'].dt.year,
    'position': dataset['position']
}).drop_duplicates()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='position', data=tmp_df)
plt.gca().xaxis.set_major_locator(MultipleLocator(0.1))
plt.show()

# %%
tmp_df = pd.DataFrame({
    'race_name': dataset['race_name'],
    'race_url': dataset['race_url'],
    'year': dataset['date'].dt.year,
    'delta': dataset['delta']
}).drop_duplicates().dropna()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='delta', data=tmp_df, log_scale=False) #TODO: check with cleaned data
plt.gca().xaxis.set_major_locator(MultipleLocator(5000))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.boxenplot(x='delta', data=tmp_df, log_scale=True) #TODO: check with cleaned data
plt.show()
# Out:
# /home/jacopo/dm/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:4779: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
tmp_df = pd.DataFrame({
    'race_name': dataset['race_name'],
    'race_url': dataset['race_url'],
    'year': dataset['date'].dt.year,
    'race_physical_effort ': dataset['race_physical_effort']
}).drop_duplicates()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='race_physical_effort ', data=tmp_df, log_scale=False)
plt.gca().xaxis.set_major_locator(MultipleLocator(0.1))
plt.show()

# %%
tmp_df = pd.DataFrame({
    'race_name': dataset['race_name'],
    'race_url': dataset['race_url'],
    'year': dataset['date'].dt.year,
    'race_prestige ': dataset['race_prestige']
}).drop_duplicates()

plt.figure(figsize=(10, 5))
sb.boxenplot(x='race_prestige ', data=tmp_df, log_scale=False)
plt.gca().xaxis.set_major_locator(MultipleLocator(0.1))
plt.show()
