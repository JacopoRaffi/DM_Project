# %% [markdown]
# # Classification
#
# ### Data Mining Project 2024/25
#
# Authors: Nicola Emmolo, Simone Marzeddu, Jacopo Raffi

# %%
#to find the best set of parameter setting, we can run a grid search
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

from sklearn import tree
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
import wittgenstein as lw
import keras_tuner
import keras
import tensorflow as tf

from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import classification_report
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score

RANDOM_STATE = 42
# Out:
# 2024-12-01 15:46:19.636053: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-01 15:46:20.119581: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733064380.266116     875 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733064380.293933     875 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-01 15:46:20.595345: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
dev_data = pd.read_csv('../data/ml_datasets/dev_set.csv').sample(frac = 1, random_state=RANDOM_STATE) # shuffling the data so not to introduce bias
testing_data = pd.read_csv('../data/ml_datasets/test_set.csv')

# %%
dev_label = dev_data.pop('label')
test_label = testing_data.pop('label')

dev_set = dev_data
test_set = testing_data

# %% [markdown]
# ## Decision Tree

# %%
#define the parameters' values you want to try
scoring_metrics = {
    'recall': 'recall',
    'precision': 'precision',
    'f1': 'f1'
}

param_dist = {"max_depth": [2,3,5,6,7,10,12,None],
              "max_features": sp_randint(1, len(dev_set.iloc[0]) + 1),
              "min_samples_split": sp_randint(10, 51),
              "min_samples_leaf": sp_randint(10, 51),
              "criterion": ["entropy", "gini"],
              "class_weight":['balanced', None, {0: 0.3, 1: 0.7}]}
#define the number of iters
n_iter_search = 200
#define the model
clf = tree.DecisionTreeClassifier()
#define the grid search
rand_search = RandomizedSearchCV(clf, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=10, 
                            scoring='f1_macro')
#run the grid search
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_score', inplace=True)
df.head()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 124       0.693100      0.048065         0.016787        0.001898
# 118       0.822170      0.075483         0.013566        0.001981
# 47        0.442645      0.017986         0.011699        0.001717
# 28        0.720582      0.078936         0.011691        0.001256
# 61        0.215958      0.028282         0.013872        0.002418
#
#     param_class_weight param_criterion param_max_depth  param_max_features  \
# 124               None         entropy            None                   8
# 118           balanced         entropy            None                  10
# 47            balanced         entropy              12                   9
# 28            balanced            gini            None                  10
# 61                None         entropy            None                   3
#
#      param_min_samples_leaf  param_min_samples_split  \
# 124                      11                       32
# 118                      20                       47
# 47                       10                       26
# 28                       38                       23
# 61                       25                       35
#
#                                                 params  split0_test_score  \
# 124  {'class_weight': None, 'criterion': 'entropy',...           0.495647
# 118  {'class_weight': 'balanced', 'criterion': 'ent...           0.505290
# 47   {'class_weight': 'balanced', 'criterion': 'ent...           0.494188
# 28   {'class_weight': 'balanced', 'criterion': 'gin...           0.497571
# 61   {'class_weight': None, 'criterion': 'entropy',...           0.495979
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 124           0.501157           0.511965           0.501459
# 118           0.495474           0.504218           0.503114
# 47            0.493700           0.503363           0.508668
# 28            0.496518           0.504316           0.501400
# 61            0.495824           0.499060           0.502563
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 124           0.505496         0.503145        0.005410                1
# 118           0.500845         0.501788        0.003484                2
# 47            0.503272         0.500638        0.005806                3
# 28            0.499492         0.499859        0.002785                4
# 61            0.505363         0.499758        0.003729                5

# %% [markdown]
# ## SVM

# %%
#define the parameters' values you want to try
param_dist = {"kernel": ['poly'],
              "C": sp_uniform(0.1, 10.0),
              "gamma": ['scale']}
#define the number of iters
n_iter_search = 1
#define the model
clf = SVC()
#define the grid search
rand_search = RandomizedSearchCV(clf, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=10, 
                            scoring='f1_macro')
#run the grid search
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_score', inplace=True)
df.head()

# %% [markdown]
# ## Naive Bayes

# %%
#define the parameters' values you want to try
scoring_metrics = {
    'recall': 'recall',
    'precision': 'precision',
    'f1': 'f1'
}

param_dist = {}
#define the number of iters
n_iter_search = 1
#define the model
clf = GaussianNB()
#define the grid search
rand_search = RandomizedSearchCV(clf, param_distributions=param_dist, #CrossValidation per confrontabilità, non model selection
                            n_iter=n_iter_search, 
                            n_jobs=1, 
                            scoring='f1_macro')
#run the grid search
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_score', inplace=True)
df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time params  \
# 0       0.040518      0.010634         0.012115        0.000611     {}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.447988           0.449436           0.449699           0.445574
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.449861         0.448512        0.001612                1

# %% [markdown]
# ## KNN

# %% [markdown]
# - Rischiamo che il mapping degli attributi categorici ordinali (senza one-hot) crei problemi nel K-NN

# %%
param_dist = {'n_neighbors': sp_randint(10, 20),
              'algorithm': ['ball_tree', 'kd_tree', 'brute'],}

tmp_dev_set = dev_set.drop(columns=['cyclist_age_group_num', 'race_season%autumn', 'race_season%spring', 'race_season%summer', 'race_season%winter'])
#define the number of iters
n_iter_search = 10
#define the model
clf = KNeighborsClassifier()
#define the grid search
rand_search = RandomizedSearchCV(clf, param_distributions=param_dist,
                            n_iter=n_iter_search, 
                            n_jobs=5, 
                            scoring='f1_macro')
#run the grid search
rand_search.fit(tmp_dev_set, dev_label);
# Out:
# /home/jacopo/dm/lib/python3.10/site-packages/numpy/ma/core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_score', inplace=True)
df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8       0.118903      0.008053         2.062970        0.015597
# 5       0.022907      0.009683        10.405033        0.092103
# 4       0.161294      0.012134         1.432873        0.108844
# 0       0.195944      0.008110         1.734364        0.044677
# 7       0.023810      0.009146        10.296053        0.139886
#
#   param_algorithm  param_n_neighbors  \
# 8       ball_tree                 11
# 5           brute                 11
# 4         kd_tree                 13
# 0         kd_tree                 15
# 7           brute                 17
#
#                                           params  split0_test_score  \
# 8  {'algorithm': 'ball_tree', 'n_neighbors': 11}           0.524240
# 5      {'algorithm': 'brute', 'n_neighbors': 11}           0.523778
# 4    {'algorithm': 'kd_tree', 'n_neighbors': 13}           0.517266
# 0    {'algorithm': 'kd_tree', 'n_neighbors': 15}           0.512730
# 7      {'algorithm': 'brute', 'n_neighbors': 17}           0.507981
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 8           0.523677           0.519810           0.516649           0.519594
# 5           0.523622           0.519810           0.516660           0.519838
# 4           0.516298           0.513040           0.512390           0.514624
# 0           0.514391           0.507889           0.510771           0.509649
# 7           0.508362           0.502046           0.506062           0.504549
#
#    mean_test_score  std_test_score  rank_test_score
# 8         0.520794        0.002821                1
# 5         0.520742        0.002678                2
# 4         0.514723        0.001857                3
# 0         0.511086        0.002281                4
# 7         0.505800        0.002326                5

# %% [markdown]
# ## Rule-Based

# %%
param_dist = {"prune_size": [0.5, 0.6], "k": [1, 3, 5]}

#define the number of iters
n_iter_search = 10
#define the model
clf = lw.RIPPER()
#define the grid search
rand_search = GridSearchCV(estimator=clf, param_grid=param_dist, scoring='f1_macro')
#run the grid search
rand_search.fit(dev_set, dev_label);
# Out:
# ripper.py: .fit | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# base.py: .predict | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# ripper.py: .fit | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# base.py: .predict | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# ripper.py: .fit | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# base.py: .predict | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# ripper.py: .fit | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# base.py: .predict | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# ripper.py: .fit | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# base.py: .predict | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# ripper.py: .fit | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# base.py: .predict | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.
#
# ripper.py: .fit | base.py: ._check_allpos_allneg: RuntimeWarning:
# Ruleset is empty. All predictions it makes with method .predict will be negative. It may be untrained or was trained on a dataset split lacking positive examples.

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_score', inplace=True)
df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_k  \
# 2      36.909321     16.776181         0.212072        0.002196        3
# 0      35.686131     16.155444         0.215591        0.007009        1
# 1      36.182507     16.355361         0.213467        0.003026        1
# 3      35.615997     16.148655         0.210887        0.003867        3
# 4      34.403325     15.518429         0.216020        0.009103        5
#
#    param_prune_size                       params  split0_test_score  \
# 2               0.5  {'k': 3, 'prune_size': 0.5}           0.398909
# 0               0.5  {'k': 1, 'prune_size': 0.5}           0.398909
# 1               0.6  {'k': 1, 'prune_size': 0.6}           0.398909
# 3               0.6  {'k': 3, 'prune_size': 0.6}           0.398909
# 4               0.5  {'k': 5, 'prune_size': 0.5}           0.398909
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 2           0.398898           0.398998           0.398898           0.398905
# 0           0.398898           0.398898           0.398898           0.398905
# 1           0.398898           0.398898           0.398898           0.398905
# 3           0.398898           0.398898           0.398898           0.398905
# 4           0.398898           0.398898           0.398898           0.398905
#
#    mean_test_score  std_test_score  rank_test_score
# 2         0.398922        0.000039                1
# 0         0.398901        0.000005                2
# 1         0.398901        0.000005                2
# 3         0.398901        0.000005                2
# 4         0.398901        0.000005                2

# %% [markdown]
# ## Random Forest

# %%
clf = RandomForestClassifier()

param_dist = {"max_depth": [2,3,5,6,7,10,12,None],
              "max_features": sp_randint(1, len(dev_set.iloc[0]) + 1),
              "min_samples_split": sp_randint(10, 51),
              "min_samples_leaf": sp_randint(10, 51),
              "criterion": ["entropy", "gini"],
              "class_weight":['balanced', None, {0: 0.3, 1: 0.7}],
              "n_estimators": [33, 100, 250]}

n_iter_search = 10
rand_search = RandomizedSearchCV(clf, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=10, 
                            scoring='f1_macro')
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_score', inplace=True)
df.head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5       18.260699      0.134818         0.149433        0.021049
# 14      82.551927      0.816631         0.598162        0.027558
# 16      27.004289      0.225192         0.208939        0.006951
# 1      106.032092      0.859685         1.092117        0.046557
# 19       1.888186      0.091144         0.069076        0.009992
#
#    param_class_weight param_criterion param_max_depth  param_max_features  \
# 5            balanced            gini              10                   9
# 14           balanced         entropy               7                   8
# 16           balanced            gini               6                   8
# 1    {0: 0.3, 1: 0.7}            gini              12                   6
# 19           balanced         entropy               5                   1
#
#     param_min_samples_leaf  param_min_samples_split  param_n_estimators  \
# 5                       24                       18                  33
# 14                      17                       38                 250
# 16                      23                       37                 100
# 1                       22                       44                 250
# 19                      32                       32                  33
#
#                                                params  split0_test_score  \
# 5   {'class_weight': 'balanced', 'criterion': 'gin...           0.602649
# 14  {'class_weight': 'balanced', 'criterion': 'ent...           0.585775
# 16  {'class_weight': 'balanced', 'criterion': 'gin...           0.579894
# 1   {'class_weight': {0: 0.3, 1: 0.7}, 'criterion'...           0.560268
# 19  {'class_weight': 'balanced', 'criterion': 'ent...           0.564336
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 5            0.598116           0.591557           0.589197
# 14           0.579370           0.582903           0.576987
# 16           0.575508           0.573466           0.568881
# 1            0.558286           0.561903           0.557129
# 19           0.565646           0.555925           0.558594
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 5            0.599099         0.596124        0.004985                1
# 14           0.581477         0.581303        0.002999                2
# 16           0.577443         0.575038        0.003741                3
# 1            0.563072         0.560132        0.002201                4
# 19           0.555011         0.559902        0.004338                5

# %% [markdown]
# ## XGBoost

# %%
clf = XGBClassifier()
param_dist = {
    "n_estimators": [25, 100, 250],
    "max_depth": [2, 3],
    "learning_rate": [1, 0.1, 0.001, 0.0001]
}
n_iter_search = 20
rand_search = RandomizedSearchCV(clf, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=10, 
                            scoring='f1_macro')
rand_search.fit(dev_set, dev_label);
# Out:
# /home/jacopo/dm/lib/python3.10/site-packages/numpy/ma/core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_score', inplace=True)
df.head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 13       2.840749      0.038625         0.116295        0.017171
# 2        1.296019      0.027099         0.064693        0.005104
# 11       2.286848      0.043136         0.082392        0.004865
# 17       0.981538      0.009600         0.031947        0.004097
# 15       0.479458      0.011165         0.032264        0.004304
#
#     param_n_estimators  param_max_depth  param_learning_rate  \
# 13                 250                3                  1.0
# 2                  100                3                  1.0
# 11                 250                2                  1.0
# 17                 100                2                  1.0
# 15                  25                3                  1.0
#
#                                                params  split0_test_score  \
# 13  {'n_estimators': 250, 'max_depth': 3, 'learnin...           0.599068
# 2   {'n_estimators': 100, 'max_depth': 3, 'learnin...           0.578340
# 11  {'n_estimators': 250, 'max_depth': 2, 'learnin...           0.561102
# 17  {'n_estimators': 100, 'max_depth': 2, 'learnin...           0.539781
# 15  {'n_estimators': 25, 'max_depth': 3, 'learning...           0.543190
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 13           0.596427           0.592772           0.593344
# 2            0.577261           0.576057           0.575633
# 11           0.561651           0.562644           0.560468
# 17           0.543231           0.542826           0.542249
# 15           0.536616           0.533579           0.540120
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 13           0.588721         0.594066        0.003503                1
# 2            0.568354         0.575129        0.003518                2
# 11           0.553330         0.559839        0.003332                3
# 17           0.537396         0.541097        0.002204                4
# 15           0.529593         0.536620        0.004776                5

# %% [markdown]
# ## AdaBoost

# %%
clf = AdaBoostClassifier()
param_dist = {
    "n_estimators": [25, 100, 250],
    "learning_rate": [1, 0.1, 0.001, 0.0001],
    "algorithm": ['SAMME']
}
n_iter_search = 10
rand_search = RandomizedSearchCV(clf, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=10, 
                            scoring='f1_macro')
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_score', inplace=True)
df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7      24.616440      0.380028         0.342425        0.044615
# 5      11.696240      0.322762         0.305693        0.016539
# 0       3.414718      0.139261         0.108733        0.007507
# 1      31.216062      1.081341         0.768117        0.014998
# 3      11.557509      0.343536         0.310554        0.018283
#
#    param_n_estimators  param_learning_rate param_algorithm  \
# 7                 250               1.0000           SAMME
# 5                 100               1.0000           SAMME
# 0                  25               1.0000           SAMME
# 1                 250               0.0001           SAMME
# 3                 100               0.0001           SAMME
#
#                                               params  split0_test_score  \
# 7  {'n_estimators': 250, 'learning_rate': 1, 'alg...           0.404902
# 5  {'n_estimators': 100, 'learning_rate': 1, 'alg...           0.402267
# 0  {'n_estimators': 25, 'learning_rate': 1, 'algo...           0.402089
# 1  {'n_estimators': 250, 'learning_rate': 0.0001,...           0.398909
# 3  {'n_estimators': 100, 'learning_rate': 0.0001,...           0.398909
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 7           0.406440           0.405923           0.405314           0.405300
# 5           0.402327           0.401861           0.405053           0.401580
# 0           0.401542           0.401684           0.401449           0.401380
# 1           0.398898           0.398898           0.398898           0.398905
# 3           0.398898           0.398898           0.398898           0.398905
#
#    mean_test_score  std_test_score  rank_test_score
# 7         0.405576        0.000541                1
# 5         0.402618        0.001248                2
# 0         0.401629        0.000252                3
# 1         0.398901        0.000005                4
# 3         0.398901        0.000005                4

# %% [markdown]
# ## Neural Network

# %%
def build_model(hp):
  model = keras.Sequential()

  units_layer1 = hp.Choice('units_layer1', [32, 64, 128])
  model.add(keras.layers.Dense(
      units_layer1,
      activation='relu')),
  model.add(keras.layers.Dropout(
        hp.Float('rate', 0, 0.5, step=0.1)
  ))
  model.add(keras.layers.Dense(
      units_layer1//2,
      activation='relu'))
  model.add(keras.layers.Dense(1, activation='sigmoid'))

  model.compile(
    optimizer='adam',
    loss='binary_crossentropy')
  
  return model

# %%
class MyHyperModel(keras_tuner.HyperModel):
    def build(self, hp):
        model = keras.Sequential()

        units_layer1 = hp.Choice('units_layer1', [32, 64, 128])
        model.add(keras.layers.Dense(
            units_layer1,
            activation='relu')),
        model.add(keras.layers.Dropout(
                hp.Float('rate', 0, 0.5, step=0.1)
        ))
        model.add(keras.layers.Dense(
            units_layer1//2,
            activation='relu'))
        model.add(keras.layers.Dense(1, activation='sigmoid'))

        model.compile(
            optimizer='adam',
            loss='binary_crossentropy')
  
        return model

    def fit(self, hp, model, *args, **kwargs):
        return model.fit(
            *args,
            batch_size=hp.Choice("batch_size", [512, 1024]),
            epochs=hp.Choice("epochs", [10, 20, 30]),
            **kwargs,
        )

# %%
tuner = keras_tuner.tuners.SklearnTuner(
    oracle=keras_tuner.oracles.BayesianOptimizationOracle(
        objective=keras_tuner.Objective('score', 'max'),
        max_trials=2),
    hypermodel=MyHyperModel(),
    scoring=metrics.make_scorer(metrics.f1_score, average='macro'),
    cv=model_selection.KFold(5))

tuner.search(dev_set, dev_label.to_numpy())
# Out:
# Trial 2 Complete [00h 00m 29s]
#
# Best score So Far: None
# Total elapsed time: 00h 00m 59s
