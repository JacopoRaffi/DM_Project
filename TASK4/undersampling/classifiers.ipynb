# %% [markdown]
# # Classification
#
# ### Data Mining Project 2024/25
#
# Authors: Nicola Emmolo, Simone Marzeddu, Jacopo Raffi

# %%
#to find the best set of parameter setting, we can run a grid search
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV, StratifiedKFold
import random
import numpy as np

from sklearn import tree
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
import wittgenstein as lw
import keras_tuner
import keras
from keras_tuner import HyperParameters
import tensorflow as tf

import matplotlib.pyplot as plt

from imblearn.under_sampling import RandomUnderSampler
from statistics import mean, stdev
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import classification_report, f1_score
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
from scipy.stats import loguniform as sp_loguniform
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score

import os
import sys
sys.path.append(os.path.abspath('../../src'))
from utils import *

# %%
RANDOM_STATE = 42
dev_data = pd.read_csv('../../data/ml_datasets/undersampling/dev_set.csv').sample(frac = 1, random_state=RANDOM_STATE) # shuffling the data so not to introduce bias
testing_data = pd.read_csv('../../data/ml_datasets/undersampling/test_set.csv')

# %%
dev_label = dev_data.pop('label')
test_label = testing_data.pop('label')

dev_set = dev_data
dev_set['race_season%autumn'] = dev_set['race_season%autumn'].astype(int)
dev_set['race_season%spring'] = dev_set['race_season%spring'].astype(int)
dev_set['race_season%summer'] = dev_set['race_season%summer'].astype(int)
dev_set['race_season%winter'] = dev_set['race_season%winter'].astype(int)

test_set = testing_data
test_set['race_season%autumn'] = test_set['race_season%autumn'].astype(int)
test_set['race_season%spring'] = test_set['race_season%spring'].astype(int)
test_set['race_season%summer'] = test_set['race_season%summer'].astype(int)
test_set['race_season%winter'] = test_set['race_season%winter'].astype(int)

N_JOBS = 8
USER = 'Jacopo'
RUS = RandomUnderSampler(random_state=RANDOM_STATE)

# %%
#define the parameters' values you want to try
def f1_class_scorer(class_index):
    def score_function(y_true, y_pred):
        # Calcola F1 per ciascuna classe e ritorna quella specificata
        return f1_score(y_true, y_pred, average=None)[class_index]
    return make_scorer(score_function)

# Scorer per la classe 0 e 1
f1_class_0 = f1_class_scorer(0)  # Classe 0
f1_class_1 = f1_class_scorer(1)  # Classe 1


scoring={
        'f1_macro': 'f1_macro',   # F1 macro per entrambe le classi
        'f1_0': f1_class_0,  # F1 solo per classe 0
        'f1_1': f1_class_1   # F1 solo per classe 1
    }

# %% [markdown]
# ## Decision Tree

# %%
param_dist = {"classifier__max_depth": [3, 5, 10, 15, 20, None],
              "classifier__max_features": sp_randint(3, len(dev_set.iloc[0]) + 1),
              "classifier__min_samples_split": [20, 30, 50, 100],
              "classifier__min_samples_leaf": [10, 20, 30, 50, 100],
              "classifier__criterion": ["entropy", "gini"],
              "classifier__class_weight":['balanced', None, {0: 0.8, 1: 0.2}, {0: 0.6, 1: 0.4}]} # class weights are related to over/undersampling chosen
#define the number of iters
n_iter_search = 1 # Total-Iteration: 400
#define the model
clf = tree.DecisionTreeClassifier()

pipeline = ImbPipeline([
    ('undersampler', RUS),  # Passo di undersampling
    ('classifier', clf)  # Il classificatore
], verbose=False)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

#define the grid search
rand_search = RandomizedSearchCV(pipeline, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=N_JOBS, 
                            scoring=scoring,
                            refit=False,
                            cv=skf)
#run the grid search
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_f1_macro', inplace=True)
df.to_csv(f'../../data/ml_datasets/undersampling/model_selection/{USER}_decision_tree_results.csv', index=False)
df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.724355      0.037454          0.05451        0.004465
#
#   param_classifier__class_weight param_classifier__criterion  \
# 0                       balanced                     entropy
#
#    param_classifier__max_depth  param_classifier__max_features  \
# 0                           20                               4
#
#    param_classifier__min_samples_leaf  param_classifier__min_samples_split  \
# 0                                  10                                  100
#
#    ... std_test_f1_0  rank_test_f1_0  split0_test_f1_1  split1_test_f1_1  \
# 0  ...      0.003437               1          0.380516          0.387482
#
#    split2_test_f1_1  split3_test_f1_1  split4_test_f1_1  mean_test_f1_1  \
# 0          0.383635          0.386537          0.381024        0.383839
#
#    std_test_f1_1  rank_test_f1_1
# 0       0.002813               1
#
# [1 rows x 35 columns]

# %% [markdown]
# ## SVM

# %%
#define the parameters' values you want to try
param_dist = {"classifier__C": sp_loguniform(1e-4, 1e2)}
#define the number of iters
n_iter_search = 50 # Total-Iteration: 100
#define the model
clf = LinearSVC()

pipeline = ImbPipeline([
    ('undersampler', RUS),  # Passo di undersampling
    ('classifier', clf)  # Il classificatore
], verbose=False)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

#define the grid search
rand_search = RandomizedSearchCV(pipeline, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=N_JOBS, 
                            scoring=scoring,
                            refit=False,
                            cv=skf)
#run the grid search
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_f1_macro', inplace=True)
df.to_csv(f'../../data/ml_datasets/undersampling/model_selection/{USER}_svm_results.csv', index=False)

# %% [markdown]
# ## Naive Bayes

# %%
#define the parameters' values you want to try
scoring_metrics = {
    'recall': 'recall',
    'precision': 'precision',
    'f1': 'f1'
}

param_dist = {}
#define the number of iters
n_iter_search = 1
#define the model
clf = GaussianNB()
pipeline = ImbPipeline([
    ('undersampler', RUS),  # Passo di undersampling
    ('classifier', clf)  # Il classificatore
], verbose=False)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

#define the grid search
rand_search = RandomizedSearchCV(pipeline, param_distributions=param_dist, # Only yo confront on the different folds, not for model selection
                            n_iter=n_iter_search, 
                            n_jobs=N_JOBS, 
                            scoring=scoring,
                            refit=False,
                            cv=skf)
#run the grid search
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_f1_macro', inplace=True)
df.to_csv(f'../../data/ml_datasets/undersampling/model_selection/{USER}_naive_bayes_results.csv', index=False)

# %% [markdown]
# ## KNN

# %% [markdown]
# - Rimuoviamo gli attributi categorici anche se codificati (potrebbero peggiorare i risultati del K-NN)

# %%
param_dist = {'classifier__n_neighbors': [5, 15, 25], # Jacopo
              #'classifier__n_neighbors': [40, 50], # Simone
              'classifier__algorithm': ['ball_tree', 'kd_tree', 'brute'],}

tmp_dev_set = dev_set.drop(columns=['cyclist_age_group', 'race_season%autumn', 'race_season%spring', 'race_season%summer', 'race_season%winter'])
#define the model
clf = KNeighborsClassifier()
pipeline = ImbPipeline([
    ('undersampler', RUS),  # Passo di undersampling
    ('classifier', clf)  # Il classificatore
], verbose=False)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

rand_search = GridSearchCV(pipeline, param_grid=param_dist,
                            n_jobs=N_JOBS, 
                            scoring=scoring,
                            refit=False,
                            cv=skf)
#run the grid search
rand_search.fit(tmp_dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_f1_macro', inplace=True)
df.to_csv(f'../../data/ml_datasets/undersampling/model_selection/{USER}_knn_results.csv', index=False)

# %% [markdown]
# ## Random Forest

# %%
clf = RandomForestClassifier()

param_dist = {"classifier__max_depth": [5, 10, 20, None],
              "classifier__max_features": sp_randint(3, len(dev_set.iloc[0]) + 1),
              "classifier__min_samples_split": [20, 50, 100],
              "classifier__min_samples_leaf": [10, 30, 50, 100],
              "classifier__criterion": ["entropy", "gini"],
              "classifier__class_weight":['balanced', None, {0: 0.8, 1: 0.2}, {0: 0.6, 1: 0.4}],
              "classifier__n_estimators": [50, 100, 150]}

n_iter_search = 50 # Total-Iteration: 100
pipeline = ImbPipeline([
    ('undersampler', RUS),  # Passo di undersampling
    ('classifier', clf)  # Il classificatore
], verbose=False)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

#define the grid search
rand_search = RandomizedSearchCV(pipeline, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=N_JOBS, 
                            scoring=scoring,
                            refit=False,
                            cv=skf)
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_f1_macro', inplace=True)
df.to_csv(f'../../data/ml_datasets/undersampling/model_selection/{USER}_random_forest_results.csv', index=False)

# %% [markdown]
# ## XGBoost

# %%
clf = XGBClassifier()
param_dist = {
    "classifier__n_estimators": [25, 50, 100], #Jacopo
    # "classifier__n_estimators": [250, 500],  Simone
    "classifier__max_depth": [2, 3, 4, 5],  
    "classifier__learning_rate": [1, 0.1, 0.01, 0.001, 0.0001] 
}

pipeline = ImbPipeline([
    ('undersampler', RUS),  # Passo di undersampling
    ('classifier', clf)  # Il classificatore
], verbose=False)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
rand_search = GridSearchCV(pipeline, param_grid=param_dist,  
                            n_jobs=N_JOBS, 
                            scoring=scoring,
                            refit=False,
                            cv=skf)
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_f1_macro', inplace=True)
df.to_csv(f'../../data/ml_datasets/undersampling/model_selection/{USER}_xgb_results.csv', index=False)

# %% [markdown]
# ## AdaBoost

# %%
clf = AdaBoostClassifier()
param_dist = {
    "classifier__n_estimators": [25, 50, 100], # Jacopo  
    # "classifier__n_estimators": [250, 500], Simone 
    "classifier__learning_rate": [1, 0.1, 0.01, 0.001, 0.0001],  
    "classifier__algorithm": ['SAMME'] 
}

pipeline = ImbPipeline([
    ('undersampler', RUS),  # Passo di undersampling
    ('classifier', clf)  # Il classificatore
], verbose=False)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
rand_search = GridSearchCV(pipeline, param_grid=param_dist,  
                            n_jobs=N_JOBS, 
                            scoring=scoring,
                            refit=False,
                            cv=skf)
rand_search.fit(dev_set, dev_label);

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_f1_macro', inplace=True)
df.to_csv(f'../../data/ml_datasets/undersampling/model_selection/{USER}_ada_boost_results.csv', index=False)

# %% [markdown]
# ## Neural Network

# %%
class MyHyperModel(keras_tuner.HyperModel):
    def build(self, hp, units, dropout_rate, learning_rate):
        model = keras.Sequential()

        model.add(keras.layers.Dense(
            units,
            activation='relu')),
        model.add(keras.layers.Dropout(rate=dropout_rate))
        model.add(keras.layers.Dense(
            units//2,
            activation='relu'))
        model.add(keras.layers.Dense(1, activation='sigmoid'))

        # Configura l'ottimizzatore con il learning rate scelto
        optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
        #f1 = keras.metrics.F1Score(average='macro', threshold=0.5, name="f1_macro", dtype=None)
        model.compile(
            optimizer=optimizer,
            loss='binary_crossentropy')
  
        return model
    
    def fit(self, hp, model, x, y, epochs, batch_size, **kwargs):
        return model.fit(
            x=x,
            y=y,
            batch_size=batch_size,
            epochs=epochs,
            verbose=False,
            **kwargs,
        )

# %%
# Parametri di KFold
dev_x = dev_set.to_numpy()
dev_y = dev_label.to_numpy()
skf = model_selection.StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)


rounds = 1
config_results = []

for _ in range(rounds):
    hp = HyperParameters()
    hyper_ae = MyHyperModel()
    batch_size = hp.Fixed("batch_size", random.choice([256, 512, 1024])) 
    epochs = hp.Fixed("epochs", random.choice([1])) 
    units_layer1 = hp.Fixed('units_layer1', random.choice([32, 64, 128, 256]))  
    drop_rate = hp.Fixed('rate', random.choice(np.arange(0., 0.9, 0.2))) 
    learning_rate = hp.Fixed("learning_rate", random.choice(np.logspace(-5, -3.5, num=10))) # Jacopo
    #learning_rate = hp.Fixed("learning_rate", random.choice(np.logspace(-3.5, -2, num=10))) Simone

    print(f"Training with batch_size={batch_size}, epochs={epochs}, units_layer1={units_layer1}, drop_rate={drop_rate}, learning_rate={learning_rate}")

    model = hyper_ae.build(hp, units_layer1, drop_rate, learning_rate)
    f1_macro_scores = []
    f1_0_scores = []
    f1_1_scores = []

    for train_index, val_index in skf.split(dev_x, dev_y):
        x_train, x_val = dev_x[train_index], dev_x[val_index]
        y_train, y_val = dev_y[train_index], dev_y[val_index]
        y_val = y_val.reshape(-1, 1)
        y_train = y_train.reshape(-1, 1)

        x_train, y_train = RUS.fit_resample(x_train, y_train)
        
        # Adatta il modello con i dati di training e validazione 
        metrics = hyper_ae.fit(hp, model, x_train, y_train, epochs=epochs, batch_size=batch_size)
        
        val_out = model.predict(x_val, verbose=False)
        val_out = (val_out >= 0.5).astype(int)
        f1_0_scores.append(f1_class_0._score_func(y_val, val_out))
        f1_1_scores.append(f1_class_1._score_func(y_val, val_out))
        f1_macro_scores.append((f1_0_scores[-1] + f1_1_scores[-1])/2)
    
    mean_f1_macro, std_f1_macro = mean(f1_macro_scores), stdev(f1_macro_scores)
    mean_f1_0, std_f1_0 = mean(f1_0_scores), stdev(f1_0_scores)
    mean_f1_1, std_f1_1 = mean(f1_1_scores), stdev(f1_1_scores)
    config = {
        "batch_size": batch_size,
        "epochs": epochs,
        "units_layer1": units_layer1,
        "units_layer2": units_layer1//2,
        "drop_rate": drop_rate,
        "learning_rate": learning_rate,
        "mean_f1_macro": mean_f1_macro,
        "std_f1_macro": std_f1_macro,
        "mean_f1_0": mean_f1_0,
        "std_f1_0": std_f1_0,
        "mean_f1_1": mean_f1_1,
        "std_f1_1": std_f1_1
    }

    config_results.append(config)

df = pd.DataFrame(config_results)
df.sort_values(by='mean_f1_macro', inplace=True, ascending=False)
df.to_csv(f'../../data/ml_datasets/undersampling/model_selection/{USER}_nn_results.csv', index=False)
# Out:
# Training with batch_size=256, epochs=1, units_layer1=64, drop_rate=0.8, learning_rate=0.00021544346900318823
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734276937.477647  143299 service.cc:148] XLA service 0x7f0150009800 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734276937.479768  143299 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4050 Laptop GPU, Compute Capability 8.9
# 2024-12-15 16:35:37.565502: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1734276937.821863  143299 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1734276939.066499  143299 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %% [markdown]
# ## Rule-Based

# %%
param_dist = {
    'classifier__prune_size': sp_uniform(0.1, 0.4),  # Distribuzione uniforme tra 0.1 e 0.5
    'classifier__k': sp_randint(1, 11)               # Interi tra 1 e 10
}

#define the number of iters
n_iter_search = 20
#define the model
clf = lw.RIPPER(
    max_rules=10,        # Moderate rule complexity
    max_rule_conds=7,    # Enough room for moderately complex conditions
    max_total_conds=35   # Cap total conditions to avoid runaway complexity
)
pipeline = ImbPipeline([
    ('undersampler', RUS),  # Passo di undersampling
    ('classifier', clf)  # Il classificatore
], verbose=False)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

#define the grid search
rand_search = RandomizedSearchCV(pipeline, param_distributions=param_dist, 
                            n_iter=n_iter_search, 
                            n_jobs=N_JOBS, 
                            scoring=scoring,
                            refit=False,
                            cv=skf)
#run the grid search
rand_search.fit(dev_set, dev_label);
# Out:
# discretizing 9 features: ['length', 'cyclist_bmi', 'climb_percentage', 'race_physical_effort', 'race_prestige', 'previous_mean_position', 'previous_mean_delta', 'previous_mean_cp', 'cyclist_previous_experience']
#
# discretizing 9 features: ['length', 'cyclist_bmi', 'climb_percentage', 'race_physical_effort', 'race_prestige', 'previous_mean_position', 'previous_mean_delta', 'previous_mean_cp', 'cyclist_previous_experience']
#
# growing ruleset...
# initial model: []
#
# pos_growset 26889 pos_pruneset 14053
# neg_growset 26889 neg_pruneset 14053
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.55^race_season%spring=1^previous_mean_cp=0.0072-0.012]
# pruned rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.55^race_season%spring=1]
# updated ruleset: [[previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.55^race_season%spring=1]]
#
# growing ruleset...
# initial model: []
#
# pos_growset 26889 pos_pruneset 14053
# neg_growset 26889 neg_pruneset 14053
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76^cyclist_age_group=1]
# pruned rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012]
# updated ruleset: [[previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012]]
#
# pos_growset 26783 pos_pruneset 13997
# neg_growset 26885 neg_pruneset 14050
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0072-0.012^cyclist_previous_experience=0.49-0.63^length=55.5-147.0]
# pruned rule unchanged
# updated ruleset: [[previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.55^race_season%spring=1] V [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0072-0.012^cyclist_previous_experience=0.49-0.63^length=55.5-147.0]]
#
# pos_growset 26696 pos_pruneset 13951
# neg_growset 26880 neg_pruneset 14047
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=0.0071-0.012^race_season%summer=0]
# pruned rule unchanged
# updated ruleset: [[previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012] V [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=0.0071-0.012^race_season%summer=0]]
#
# pos_growset 26760 pos_pruneset 13985
# neg_growset 26884 neg_pruneset 14050
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_previous_experience=0.39-0.49^climb_percentage=>0.025]
# pruned rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_previous_experience=0.39-0.49]
# updated ruleset: ...[[previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0072-0.012^cyclist_previous_experience=0.49-0.63^length=55.5-147.0] V [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_previous_experience=0.39-0.49]]
#
# pos_growset 26670 pos_pruneset 13938
# neg_growset 26880 neg_pruneset 14047
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^climb_percentage=0.021-0.025^cyclist_previous_experience=0.49-0.63]
# pruned rule unchanged
# updated ruleset: ...[[previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=0.0071-0.012^race_season%summer=0] V [previous_mean_position=<0.28^race_season%summer=0^climb_percentage=0.021-0.025^cyclist_previous_experience=0.49-0.63]]
#
# pos_growset 26668 pos_pruneset 13937
# neg_growset 26880 neg_pruneset 14048
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012^cyclist_age_group=2]
# pruned rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012]
# updated ruleset: ...[[previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_previous_experience=0.39-0.49] V [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012]]
#
# pos_growset 26626 pos_pruneset 13915
# neg_growset 26878 neg_pruneset 14046
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^cyclist_age_group=2^cyclist_bmi=21.1-21.38]
# pruned rule unchanged
# updated ruleset: ...[[previous_mean_position=<0.28^race_season%summer=0^climb_percentage=0.021-0.025^cyclist_previous_experience=0.49-0.63] V [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^cyclist_age_group=2^cyclist_bmi=21.1-21.38]]
#
# pos_growset 26553 pos_pruneset 13877
# neg_growset 26870 neg_pruneset 14042
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^previous_mean_delta=<160.55]
# pruned rule unchanged
# updated ruleset: ...[[previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012] V [previous_mean_position=<0.28^climb_percentage=>0.025^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^previous_mean_delta=<160.55]]
#
# pos_growset 26604 pos_pruneset 13903
# neg_growset 26877 neg_pruneset 14046
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=>0.012^race_season%winter=0^climb_percentage=>0.025]
# pruned rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=>0.012^race_season%winter=0]
# updated ruleset: ...[[previous_mean_position=<0.28^race_physical_effort=0.29-0.4^cyclist_age_group=2^cyclist_bmi=21.1-21.38] V [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=>0.012^race_season%winter=0]]
#
# pos_growset 26518 pos_pruneset 13859
# neg_growset 26869 neg_pruneset 14042
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_cp=0.0072-0.012^previous_mean_delta=<160.55^cyclist_bmi=19.47-20.02]
# pruned rule: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_cp=0.0072-0.012]
# updated ruleset: ...[[previous_mean_position=<0.28^climb_percentage=>0.025^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^previous_mean_delta=<160.55] V [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_cp=0.0072-0.012]]
#
# pos_growset 26524 pos_pruneset 13862
# neg_growset 26874 neg_pruneset 14044
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^previous_mean_delta=<160.76^climb_percentage=0.013-0.016^previous_mean_cp=0.0071-0.012]
# pruned rule unchanged
# updated ruleset: ...[[previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=>0.012^race_season%winter=0] V [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^previous_mean_delta=<160.76^climb_percentage=0.013-0.016^previous_mean_cp=0.0071-0.012]]
#
# pos_growset 26351 pos_pruneset 13771
# neg_growset 26851 neg_pruneset 14033
# grew rule: [previous_mean_position=<0.28^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^cyclist_previous_experience=>0.63^race_season%summer=0^race_prestige=<0.066]
# pruned rule: [previous_mean_position=<0.28^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^cyclist_previous_experience=>0.63^race_season%summer=0]
# updated ruleset: ...[[previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_cp=0.0072-0.012] V [previous_mean_position=<0.28^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^cyclist_previous_experience=>0.63^race_season%summer=0]]
#
# pos_growset 26504 pos_pruneset 13851
# neg_growset 26874 neg_pruneset 14044
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.018-0.021^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76^cyclist_bmi=<19.49]
# pruned rule: [previous_mean_position=<0.28^climb_percentage=0.018-0.021^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76]
# updated ruleset: ...[[previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^previous_mean_delta=<160.76^climb_percentage=0.013-0.016^previous_mean_cp=0.0071-0.012] V [previous_mean_position=<0.28^climb_percentage=0.018-0.021^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76]]
#
# pos_growset 26254 pos_pruneset 13721
# neg_growset 26844 neg_pruneset 14029
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=>0.012^cyclist_age_group=4]
# pruned rule unchanged
# updated ruleset: ...[[previous_mean_position=<0.28^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^cyclist_previous_experience=>0.63^race_season%summer=0] V [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=>0.012^cyclist_age_group=4]]
#
# pos_growset 26407 pos_pruneset 13801
# neg_growset 26866 neg_pruneset 14041
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.49^previous_mean_cp=0.004-0.0052]
# pruned rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.49]
# updated ruleset: ...[[previous_mean_position=<0.28^climb_percentage=0.018-0.021^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76] V [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.49]]
#
# pos_growset 26219 pos_pruneset 13703
# neg_growset 26844 neg_pruneset 14029
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.47^race_season%winter=0^race_physical_effort=0.29-0.4]
# pruned rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.47]
# updated ruleset: ...[[previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=>0.012^cyclist_age_group=4] V [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.47]]
#
# pos_growset 26283 pos_pruneset 13736
# neg_growset 26855 neg_pruneset 14035
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^cyclist_age_group=1^race_prestige=0.078-0.097]
# pruned rule unchanged
# updated ruleset: ...[[previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.49] V [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^cyclist_age_group=1^race_prestige=0.078-0.097]]
#
#
# GREW INITIAL RULESET:
# [[previous_mean_position=<0.28 ^ race_physical_effort=>0.4 ^ previous_mean_delta=<160.55 ^ race_season%spring=1] V
# [previous_mean_position=<0.28 ^ climb_percentage=>0.025 ^ previous_mean_cp=0.0072-0.012 ^ cyclist_previous_experience=0.49-0.63 ^ length=55.5-147.0] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4 ^ cyclist_previous_experience=0.39-0.49] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.29-0.4 ^ previous_mean_delta=<160.55 ^ previous_mean_cp=0.0072-0.012] V
# [previous_mean_position=<0.28 ^ climb_percentage=>0.025 ^ cyclist_bmi=19.47-20.02 ^ previous_mean_cp=0.0052-0.0072 ^ previous_mean_delta=<160.55] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.2-0.29 ^ previous_mean_cp=0.0072-0.012] V
# [previous_mean_position=<0.28 ^ cyclist_bmi=19.47-20.02 ^ previous_mean_cp=0.0052-0.0072 ^ cyclist_previous_experience=>0.63 ^ race_season%summer=0] V
# [previous_mean_position=<0.28 ^ climb_percentage=>0.025 ^ previous_mean_cp=>0.012 ^ cyclist_age_group=4] V
# [previous_mean_position=<0.28 ^ climb_percentage=0.021-0.025 ^ cyclist_bmi=<19.47]]
#
# optimization run 1 of 5
# optimizing ruleset...
#
#
# GREW INITIAL RULESET:
# [[previous_mean_position=<0.28 ^ climb_percentage=>0.025 ^ previous_mean_cp=0.0071-0.012] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4 ^ previous_mean_delta=<160.76 ^ previous_mean_cp=0.0071-0.012 ^ race_season%summer=0] V
# [previous_mean_position=<0.28 ^ race_season%summer=0 ^ climb_percentage=0.021-0.025 ^ cyclist_previous_experience=0.49-0.63] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.29-0.4 ^ cyclist_age_group=2 ^ cyclist_bmi=21.1-21.38] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4 ^ previous_mean_delta=<160.76 ^ previous_mean_cp=>0.012 ^ race_season%winter=0] V
# [previous_mean_position=<0.28 ^ race_season%summer=0 ^ race_physical_effort=0.2-0.29 ^ previous_mean_delta=<160.76 ^ climb_percentage=0.013-0.016 ^ previous_mean_cp=0.0071-0.012] V
# [previous_mean_position=<0.28 ^ climb_percentage=0.018-0.021 ^ previous_mean_cp=0.0071-0.012 ^ previous_mean_delta=<160.76] V
# [previous_mean_position=<0.28 ^ climb_percentage=0.021-0.025 ^ cyclist_bmi=<19.49] V
# [previous_mean_position=<0.28 ^ race_season%summer=0 ^ race_physical_effort=0.2-0.29 ^ cyclist_age_group=1 ^ race_prestige=0.078-0.097]]
#
# optimization run 1 of 5
# optimizing ruleset...
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.55^race_season%spring=1^cyclist_bmi=19.47-20.02]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.55^race_season%spring=1^cyclist_bmi=19.47-20.02]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012^cyclist_bmi=21.1-21.38^race_season%spring=0]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012^cyclist_bmi=21.1-21.38^race_season%spring=0]
#
# rule 1 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.55^race_season%spring=1]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
#
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012^race_season%summer=1^race_prestige=0.26-0.29]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0072-0.012^cyclist_previous_experience=0.49-0.63^length=55.5-147.0]
#
# rule 1 of 9
# original: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=0.0071-0.012^race_season%summer=0]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=0.0071-0.012^race_season%summer=0]
#
# rule 2 of 9
# original: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0072-0.012^cyclist_previous_experience=0.49-0.63^length=55.5-147.0]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^previous_mean_cp=0.0052-0.0072^race_physical_effort=>0.4^previous_mean_delta=<160.55]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_previous_experience=0.39-0.49^race_season%summer=0]
#
# rule 2 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=0.0071-0.012^race_season%summer=0]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^cyclist_bmi=<19.49^cyclist_age_group=1]
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^climb_percentage=0.021-0.025^cyclist_previous_experience=0.49-0.63^previous_mean_delta=<160.76]
#
# rule 3 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_previous_experience=0.39-0.49]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^race_prestige=0.11-0.12^previous_mean_delta=<160.55]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012^cyclist_previous_experience=0.49-0.63^climb_percentage=0.021-0.025]
#
# rule 3 of 9
# original: [previous_mean_position=<0.28^race_season%summer=0^climb_percentage=0.021-0.025^cyclist_previous_experience=0.49-0.63]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0052-0.0071^length=55.5-147.0^previous_mean_delta=<160.76^cyclist_bmi=<19.49]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^cyclist_age_group=2^cyclist_bmi=21.1-21.38^previous_mean_delta=<160.76]
#
# rule 4 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^race_season%spring=1^length=55.5-147.0]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^previous_mean_delta=<160.55^length=55.5-147.0]
#
# rule 4 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^cyclist_age_group=2^cyclist_bmi=21.1-21.38]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^cyclist_age_group=1^climb_percentage=0.021-0.025]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=>0.012^race_season%winter=0^cyclist_age_group=3]
#
# rule 5 of 9
# original: [previous_mean_position=<0.28^climb_percentage=>0.025^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^previous_mean_delta=<160.55]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^race_season%spring=1^length=147.0-161.0]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_cp=0.0072-0.012^previous_mean_delta=<160.55^race_season%winter=0^climb_percentage=0.013-0.016]
#
# rule 5 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=>0.012^race_season%winter=0]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^previous_mean_delta=<160.76^cyclist_previous_experience=0.49-0.63^race_season%winter=0]
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^previous_mean_delta=<160.76^climb_percentage=0.013-0.016^previous_mean_cp=0.0071-0.012]
#
# rule 6 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_cp=0.0072-0.012]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^race_prestige=0.096-0.11^race_season%spring=1]
# grew rule: [previous_mean_position=<0.28^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^cyclist_previous_experience=>0.63^race_season%summer=0^previous_mean_delta=160.55-210.49]
#
# rule 6 of 9
# original: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^previous_mean_delta=<160.76^climb_percentage=0.013-0.016^previous_mean_cp=0.0071-0.012]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_cp=0.0052-0.0071^length=207.5-227.0^race_season%summer=0]
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.018-0.021^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76^race_season%spring=0^race_physical_effort=0.2-0.29]
#
# rule 7 of 9
# original: [previous_mean_position=<0.28^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^cyclist_previous_experience=>0.63^race_season%summer=0]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^climb_percentage=0.018-0.021^race_season%summer=1^length=187.9-197.82]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=>0.012^cyclist_age_group=4]
#
# rule 7 of 9
# original: [previous_mean_position=<0.28^climb_percentage=0.018-0.021^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^previous_mean_cp=0.0052-0.0071^cyclist_previous_experience=>0.63^cyclist_bmi=<19.49^race_physical_effort=0.14-0.2]
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.49^cyclist_age_group=0]
#
# rule 8 of 9
# original: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=>0.012^cyclist_age_group=4]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^cyclist_age_group=0^race_prestige=0.096-0.11^cyclist_bmi=21.11-21.39]
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.47^race_season%winter=0^previous_mean_delta=160.55-210.49]
#
# rule 8 of 9
# original: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.49]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^race_season%spring=1^length=<55.5^previous_mean_cp=>0.012]
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^cyclist_age_group=1^race_prestige=0.078-0.097^race_season%autumn=0]
#
# rule 9 of 9
# original: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.47]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
#
# OPTIMIZED RULESET:
# iteration 1 of 5
#  modified rules [0]
# [[previous_mean_position=<0.28] V
# [previous_mean_position=<0.28 ^ climb_percentage=>0.025 ^ previous_mean_cp=0.0072-0.012 ^ cyclist_previous_experience=0.49-0.63 ^ length=55.5-147.0] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4 ^ cyclist_previous_experience=0.39-0.49] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.29-0.4 ^ previous_mean_delta=<160.55 ^ previous_mean_cp=0.0072-0.012] V
# [previous_mean_position=<0.28 ^ climb_percentage=>0.025 ^ cyclist_bmi=19.47-20.02 ^ previous_mean_cp=0.0052-0.0072 ^ previous_mean_delta=<160.55] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.2-0.29 ^ previous_mean_cp=0.0072-0.012] V
# [previous_mean_position=<0.28 ^ cyclist_bmi=19.47-20.02 ^ previous_mean_cp=0.0052-0.0072 ^ cyclist_previous_experience=>0.63 ^ race_season%summer=0] V
# [previous_mean_position=<0.28 ^ climb_percentage=>0.025 ^ previous_mean_cp=>0.012 ^ cyclist_age_group=4] V
# [previous_mean_position=<0.28 ^ climb_percentage=0.021-0.025 ^ cyclist_bmi=<19.47]]
#
# optimization run 2 of 5
# optimizing ruleset...
#
#
# rule 9 of 9
# original: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^cyclist_age_group=1^race_prestige=0.078-0.097]
# replacement: [previous_mean_position=<0.28]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=<0.28]
# best already included in optimization -- retaining original
#
#
# OPTIMIZED RULESET:
# iteration 1 of 5
#  modified rules [0]
# [[previous_mean_position=<0.28] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4 ^ previous_mean_delta=<160.76 ^ previous_mean_cp=0.0071-0.012 ^ race_season%summer=0] V
# [previous_mean_position=<0.28 ^ race_season%summer=0 ^ climb_percentage=0.021-0.025 ^ cyclist_previous_experience=0.49-0.63] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.29-0.4 ^ cyclist_age_group=2 ^ cyclist_bmi=21.1-21.38] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4 ^ previous_mean_delta=<160.76 ^ previous_mean_cp=>0.012 ^ race_season%winter=0] V
# [previous_mean_position=<0.28 ^ race_season%summer=0 ^ race_physical_effort=0.2-0.29 ^ previous_mean_delta=<160.76 ^ climb_percentage=0.013-0.016 ^ previous_mean_cp=0.0071-0.012] V
# [previous_mean_position=<0.28 ^ climb_percentage=0.018-0.021 ^ previous_mean_cp=0.0071-0.012 ^ previous_mean_delta=<160.76] V
# [previous_mean_position=<0.28 ^ climb_percentage=0.021-0.025 ^ cyclist_bmi=<19.49] V
# [previous_mean_position=<0.28 ^ race_season%summer=0 ^ race_physical_effort=0.2-0.29 ^ cyclist_age_group=1 ^ race_prestige=0.078-0.097]]
#
# optimization run 2 of 5
# optimizing ruleset...
#
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_delta=<160.55^length=55.5-147.0^race_season%spring=0^race_physical_effort=0.2-0.29]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_delta=<160.55^length=55.5-147.0^race_season%spring=0^race_physical_effort=0.2-0.29]
#
# rule 1 of 9
# original: [previous_mean_position=<0.28]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^climb_percentage=>0.025^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012^cyclist_bmi=21.72-22.2]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0072-0.012^cyclist_previous_experience=0.49-0.63^length=55.5-147.0]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012^cyclist_age_group=2^race_season%winter=0]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012^cyclist_age_group=2^race_season%winter=0]
#
# rule 1 of 9
# original: [previous_mean_position=<0.28]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_season%summer=0^race_physical_effort=>0.4^previous_mean_delta=<160.76^cyclist_age_group=4]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=0.0071-0.012^race_season%summer=0]
#
# rule 2 of 9
# original: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0072-0.012^cyclist_previous_experience=0.49-0.63^length=55.5-147.0]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
#
# grew rule: [previous_mean_position=0.28-0.33^climb_percentage=>0.025^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012^race_season%spring=0]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_previous_experience=0.39-0.49]
#
# rule 2 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=0.0071-0.012^race_season%summer=0]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
#
# grew rule: [previous_mean_position=0.28-0.33^race_season%summer=0^climb_percentage=0.021-0.025^previous_mean_delta=<160.76^previous_mean_cp=0.004-0.0052]
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^climb_percentage=0.021-0.025^cyclist_previous_experience=0.49-0.63]
#
# rule 3 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_previous_experience=0.39-0.49]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.55^cyclist_age_group=1]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012]
#
# rule 3 of 9
# original: [previous_mean_position=<0.28^race_season%summer=0^climb_percentage=0.021-0.025^cyclist_previous_experience=0.49-0.63]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_season%summer=0^cyclist_age_group=0^previous_mean_delta=210.82-263.4^race_physical_effort=>0.4]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^cyclist_age_group=2^cyclist_bmi=21.1-21.38]
#
# rule 4 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_season%summer=0^race_physical_effort=0.2-0.29^race_season%spring=0^cyclist_previous_experience=0.39-0.49]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^previous_mean_delta=<160.55]
#
# rule 4 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^cyclist_age_group=2^cyclist_bmi=21.1-21.38]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_season%summer=0^climb_percentage=>0.025^previous_mean_delta=<160.76^race_season%spring=1^race_physical_effort=>0.4]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=>0.012^race_season%winter=0]
#
# rule 5 of 9
# original: [previous_mean_position=<0.28^climb_percentage=>0.025^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^previous_mean_delta=<160.55]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.55^cyclist_age_group=1]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_cp=0.0072-0.012]
#
# rule 5 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=>0.012^race_season%winter=0]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.76^length=207.5-227.0]
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^previous_mean_delta=<160.76^climb_percentage=0.013-0.016^previous_mean_cp=0.0071-0.012]
#
# rule 6 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_cp=0.0072-0.012]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.55^cyclist_age_group=1]
# grew rule: [previous_mean_position=<0.28^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^cyclist_previous_experience=>0.63^race_season%summer=0]
#
# rule 6 of 9
# original: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^previous_mean_delta=<160.76^climb_percentage=0.013-0.016^previous_mean_cp=0.0071-0.012]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.76^length=207.5-227.0]
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.018-0.021^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76]
#
# rule 7 of 9
# original: [previous_mean_position=<0.28^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^cyclist_previous_experience=>0.63^race_season%summer=0]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.55^climb_percentage=>0.025^previous_mean_cp=0.0072-0.012]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=>0.012^cyclist_age_group=4]
#
# rule 7 of 9
# original: [previous_mean_position=<0.28^climb_percentage=0.018-0.021^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=0.2-0.29^race_season%summer=0^length=>227.0^previous_mean_cp=0.004-0.0052]
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.49]
#
# rule 8 of 9
# original: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=>0.012^cyclist_age_group=4]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.55^climb_percentage=>0.025^previous_mean_cp=0.0072-0.012]
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.47]
#
# rule 8 of 9
# original: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.49]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_season%summer=0^cyclist_age_group=0^race_season%spring=0^previous_mean_cp=0.004-0.0052^race_prestige=0.078-0.097]
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^cyclist_age_group=1^race_prestige=0.078-0.097]
#
# rule 9 of 9
# original: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.47]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
#
# OPTIMIZED RULESET:
# iteration 2 of 5
#  modified rules [1]
# [[previous_mean_position=<0.28] V
# [previous_mean_position=0.28-0.33] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4 ^ cyclist_previous_experience=0.39-0.49] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.29-0.4 ^ previous_mean_delta=<160.55 ^ previous_mean_cp=0.0072-0.012] V
# [previous_mean_position=<0.28 ^ climb_percentage=>0.025 ^ cyclist_bmi=19.47-20.02 ^ previous_mean_cp=0.0052-0.0072 ^ previous_mean_delta=<160.55] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.2-0.29 ^ previous_mean_cp=0.0072-0.012] V
# [previous_mean_position=<0.28 ^ cyclist_bmi=19.47-20.02 ^ previous_mean_cp=0.0052-0.0072 ^ cyclist_previous_experience=>0.63 ^ race_season%summer=0] V
# [previous_mean_position=<0.28 ^ climb_percentage=>0.025 ^ previous_mean_cp=>0.012 ^ cyclist_age_group=4] V
# [previous_mean_position=<0.28 ^ climb_percentage=0.021-0.025 ^ cyclist_bmi=<19.47]]
#
# optimization run 3 of 5
# optimizing ruleset...
#
#
# rule 9 of 9
# original: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^cyclist_age_group=1^race_prestige=0.078-0.097]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.28-0.33]
# best already included in optimization -- retaining original
#
#
# OPTIMIZED RULESET:
# iteration 2 of 5
#  modified rules [1]
# [[previous_mean_position=<0.28] V
# [previous_mean_position=0.28-0.33] V
# [previous_mean_position=<0.28 ^ race_season%summer=0 ^ climb_percentage=0.021-0.025 ^ cyclist_previous_experience=0.49-0.63] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.29-0.4 ^ cyclist_age_group=2 ^ cyclist_bmi=21.1-21.38] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4 ^ previous_mean_delta=<160.76 ^ previous_mean_cp=>0.012 ^ race_season%winter=0] V
# [previous_mean_position=<0.28 ^ race_season%summer=0 ^ race_physical_effort=0.2-0.29 ^ previous_mean_delta=<160.76 ^ climb_percentage=0.013-0.016 ^ previous_mean_cp=0.0071-0.012] V
# [previous_mean_position=<0.28 ^ climb_percentage=0.018-0.021 ^ previous_mean_cp=0.0071-0.012 ^ previous_mean_delta=<160.76] V
# [previous_mean_position=<0.28 ^ climb_percentage=0.021-0.025 ^ cyclist_bmi=<19.49] V
# [previous_mean_position=<0.28 ^ race_season%summer=0 ^ race_physical_effort=0.2-0.29 ^ cyclist_age_group=1 ^ race_prestige=0.078-0.097]]
#
# optimization run 3 of 5
# optimizing ruleset...
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.55^race_season%spring=1^cyclist_previous_experience=0.49-0.63]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.55^race_season%spring=1^cyclist_previous_experience=0.49-0.63]
#
# rule 1 of 9
# original: [previous_mean_position=<0.28]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.55^cyclist_age_group=0]
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.55^cyclist_age_group=0]
#
# rule 2 of 9
# original: [previous_mean_position=0.28-0.33]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.33-0.38^race_season%summer=0^climb_percentage=>0.025^cyclist_bmi=<19.47^cyclist_age_group=3]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_previous_experience=0.39-0.49]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012^cyclist_age_group=2^race_season%winter=0]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012^cyclist_age_group=2^race_season%winter=0]
#
# rule 1 of 9
# original: [previous_mean_position=<0.28]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.76^length=>227.0]
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<160.76^length=>227.0]
#
# rule 2 of 9
# original: [previous_mean_position=0.28-0.33]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
#
# rule 3 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_previous_experience=0.39-0.49]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
#
# grew rule: [previous_mean_position=0.33-0.38^race_season%summer=0^previous_mean_cp=0.0071-0.012^length=<55.5^climb_percentage=>0.025]
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^climb_percentage=0.021-0.025^cyclist_previous_experience=0.49-0.63]
# grew rule: [previous_mean_position=0.33-0.38^race_prestige=>0.29^cyclist_bmi=20.02-20.45^previous_mean_cp=0.0021-0.0026]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012]
#
# rule 3 of 9
# original: [previous_mean_position=<0.28^race_season%summer=0^climb_percentage=0.021-0.025^cyclist_previous_experience=0.49-0.63]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
#
#
# rule 4 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<160.55^previous_mean_cp=0.0072-0.012]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.33-0.38^climb_percentage=>0.025^previous_mean_delta=160.76-210.82^cyclist_previous_experience=>0.63]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^cyclist_age_group=2^cyclist_bmi=21.1-21.38]
# grew rule: [previous_mean_position=0.33-0.38^race_season%summer=0^length=>226.64^race_prestige=>0.29^previous_mean_delta=160.55-210.49^climb_percentage=0.016-0.018]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^previous_mean_delta=<160.55]
#
# rule 4 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^cyclist_age_group=2^cyclist_bmi=21.1-21.38]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
#
# rule 5 of 9
# original: [previous_mean_position=<0.28^climb_percentage=>0.025^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^previous_mean_delta=<160.55]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.33-0.38^climb_percentage=>0.025^previous_mean_delta=160.76-210.82^race_season%summer=0^cyclist_age_group=2]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=>0.012^race_season%winter=0]
# grew rule: [previous_mean_position=0.33-0.38^race_season%summer=0^length=>226.64^previous_mean_cp=0.004-0.0052^race_season%spring=0]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_cp=0.0072-0.012]
#
# rule 5 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<160.76^previous_mean_cp=>0.012^race_season%winter=0]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
#
# rule 6 of 9
# original: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_cp=0.0072-0.012]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.33-0.38^climb_percentage=>0.025^previous_mean_delta=160.76-210.82^cyclist_previous_experience=>0.63]
# grew rule: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^previous_mean_delta=<160.76^climb_percentage=0.013-0.016^previous_mean_cp=0.0071-0.012]
# grew rule: [previous_mean_position=0.33-0.38^race_season%summer=0^climb_percentage=>0.025^race_physical_effort=>0.4^race_season%winter=0^previous_mean_cp=0.0052-0.0072]
# grew rule: [previous_mean_position=<0.28^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^cyclist_previous_experience=>0.63^race_season%summer=0]
#
# rule 6 of 9
# original: [previous_mean_position=<0.28^race_season%summer=0^race_physical_effort=0.2-0.29^previous_mean_delta=<160.76^climb_percentage=0.013-0.016^previous_mean_cp=0.0071-0.012]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
#
# rule 7 of 9
# original: [previous_mean_position=<0.28^cyclist_bmi=19.47-20.02^previous_mean_cp=0.0052-0.0072^cyclist_previous_experience=>0.63^race_season%summer=0]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.33-0.38^climb_percentage=>0.025^previous_mean_delta=160.76-210.82^race_season%summer=0^race_prestige=0.097-0.11]
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.018-0.021^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76]
# grew rule: [previous_mean_position=0.33-0.38^race_season%summer=0^length=>226.64^cyclist_age_group=2^previous_mean_delta=312.81-368.54^race_prestige=>0.29]
# grew rule: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=>0.012^cyclist_age_group=4]
#
# rule 7 of 9
# original: [previous_mean_position=<0.28^climb_percentage=0.018-0.021^previous_mean_cp=0.0071-0.012^previous_mean_delta=<160.76]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
#
# rule 8 of 9
# original: [previous_mean_position=<0.28^climb_percentage=>0.025^previous_mean_cp=>0.012^cyclist_age_group=4]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.33-0.38^race_prestige=>0.29^race_season%autumn=1^race_physical_effort=0.2-0.29]
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.49]
# grew rule: [previous_mean_position=0.33-0.38^race_prestige=>0.29^previous_mean_delta=160.55-210.49^race_physical_effort=>0.4^cyclist_age_group=1]
# grew rule: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.47]
#
# rule 8 of 9
# original: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.49]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
#
# rule 9 of 9
# original: [previous_mean_position=<0.28^climb_percentage=0.021-0.025^cyclist_bmi=<19.47]
# replacement: [previous_mean_position=0.33-0.38]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.33-0.38]
# best already included in optimization -- retaining original
#
#
# OPTIMIZED RULESET:
# iteration 3 of 5
#  modified rules [2]
# [[previous_mean_position=<0.28] V
# [previous_mean_position=0.28-0.33] V
# [previous_mean_position=0.33-0.38] V
# ...
#
# optimization run 4 of 5
# optimizing ruleset...
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<161.11^cyclist_bmi=19.47-20.02^climb_percentage=>0.025]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^previous_mean_delta=<161.11^cyclist_bmi=19.47-20.02^climb_percentage=>0.025]
#
# rule 1 of 10
# original: [previous_mean_position=<0.28]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_season%summer=0^race_physical_effort=>0.4^previous_mean_delta=<161.11^length=188.0-197.5]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4]
#
# rule 2 of 10
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<161.11^previous_mean_cp=0.0071-0.012^race_season%spring=0]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<161.11]
#
# rule 3 of 10
# original: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<161.11]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<161.11^cyclist_previous_experience=>0.63^race_season%spring=0]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_delta=<161.11^cyclist_previous_experience=>0.63]
#
# rule 4 of 10
# original: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_delta=<161.11^cyclist_previous_experience=>0.63]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<161.11^previous_mean_cp=0.0071-0.012^climb_percentage=>0.025]
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<161.11^previous_mean_cp=0.0071-0.012^climb_percentage=>0.025]
#
# rule 5 of 10
# original: [previous_mean_position=0.28-0.33]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.33-0.38^race_season%summer=0^previous_mean_cp=0.0071-0.012^race_season%spring=0^cyclist_bmi=21.1-21.38^length=>226.5]
# grew rule: [previous_mean_position=0.33-0.38^race_season%summer=0^previous_mean_cp=0.0071-0.012^race_season%spring=0^cyclist_bmi=21.1-21.38^length=>226.5]
#
# rule 6 of 10
# original: [previous_mean_position=0.33-0.38]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.38-0.42^cyclist_age_group=1^race_season%summer=0^cyclist_previous_experience=0.24-0.31^previous_mean_delta=263.07-313.3^climb_percentage=>0.025]
# grew rule: [previous_mean_position=0.38-0.42^cyclist_age_group=1^race_season%summer=0^cyclist_previous_experience=0.24-0.31^previous_mean_delta=263.07-313.3^climb_percentage=>0.025]
#
# rule 7 of 10
# original: [previous_mean_position=0.38-0.42]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.42-0.46^race_season%summer=0^length=>226.5^race_prestige=>0.29^climb_percentage=<0.0054^cyclist_age_group=4^previous_mean_delta=424.68-482.0]
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=0.29-0.4^previous_mean_cp=0.0071-0.012^race_season%summer=0]
#
# rule 8 of 10
# original: [previous_mean_position=0.28-0.33^race_physical_effort=0.29-0.4^previous_mean_cp=0.0071-0.012^race_season%summer=0]
# replacement: [previous_mean_position=0.42-0.46^race_season%summer=0]
# revision: [previous_mean_position=0.28-0.33]
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.42-0.46^cyclist_age_group=0^race_season%summer=0^cyclist_previous_experience=0.077-0.13^previous_mean_delta=263.07-313.3^length=161.0-170.0]
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=0.2-0.29^previous_mean_delta=161.11-210.65]
#
# rule 9 of 10
# original: [previous_mean_position=0.28-0.33^race_physical_effort=0.2-0.29^previous_mean_delta=161.11-210.65]
# replacement: [previous_mean_position=0.42-0.46^cyclist_age_group=0]
# revision: [previous_mean_position=0.28-0.33]
# *best: [previous_mean_position=0.42-0.46^cyclist_age_group=0]
#
# grew rule: [previous_mean_position=0.42-0.46^race_season%summer=0^cyclist_age_group=0^cyclist_previous_experience=0.077-0.13^previous_mean_delta=263.07-313.3^length=161.0-170.0]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.14-0.2^previous_mean_cp=0.0071-0.012^race_season%winter=0^cyclist_previous_experience=0.48-0.63]
#
# rule 10 of 10
# original: [previous_mean_position=<0.28^race_physical_effort=0.14-0.2^previous_mean_cp=0.0071-0.012^race_season%winter=0^cyclist_previous_experience=0.48-0.63]
# replacement: [previous_mean_position=0.42-0.46^race_season%summer=0]
# revision: [previous_mean_position=<0.28]
# *best: unchanged
# best already included in optimization -- retaining original
#
#
# OPTIMIZED RULESET:
# iteration 4 of 5
#  modified rules [8]
# [[previous_mean_position=<0.28] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.29-0.4 ^ previous_mean_delta=<161.11] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.2-0.29 ^ previous_mean_delta=<161.11 ^ cyclist_previous_experience=>0.63] V
# [previous_mean_position=0.28-0.33] V
# [previous_mean_position=0.33-0.38] V
# [previous_mean_position=0.38-0.42] V
# [previous_mean_position=0.28-0.33 ^ race_physical_effort=0.29-0.4 ^ previous_mean_cp=0.0071-0.012 ^ race_season%summer=0] V
# [previous_mean_position=0.42-0.46 ^ cyclist_age_group=0] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.14-0.2 ^ previous_mean_cp=0.0071-0.012 ^ race_season%winter=0 ^ cyclist_previous_experience=0.48-0.63]]
#
# optimization run 5 of 5
# optimizing ruleset...
#
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_bmi=19.47-20.02^previous_mean_delta=<161.11^climb_percentage=>0.025]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4^cyclist_bmi=19.47-20.02^previous_mean_delta=<161.11^climb_percentage=>0.025]
#
# rule 1 of 10
# original: [previous_mean_position=<0.28]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<161.11^climb_percentage=>0.025^previous_mean_cp=0.0071-0.012]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=>0.4]
#
# rule 2 of 10
# original: [previous_mean_position=<0.28^race_physical_effort=>0.4]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_season%summer=0^climb_percentage=0.021-0.025^length=147.0-161.0]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<161.11]
#
# rule 3 of 10
# original: [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<161.11]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_season%summer=0^climb_percentage=0.016-0.018^previous_mean_cp=0.0052-0.0071^race_physical_effort=0.2-0.29]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_delta=<161.11^cyclist_previous_experience=>0.63]
#
# rule 4 of 10
# original: [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_delta=<161.11^cyclist_previous_experience=>0.63]
# replacement: [previous_mean_position=0.28-0.33]
# revision: [previous_mean_position=<0.28]
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<161.11^previous_mean_cp=0.0071-0.012^cyclist_bmi=21.72-22.2]
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=>0.4^previous_mean_delta=<161.11^previous_mean_cp=0.0071-0.012^cyclist_bmi=21.72-22.2]
#
# rule 5 of 10
# original: [previous_mean_position=0.28-0.33]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.33-0.38^race_season%summer=0^previous_mean_cp=0.0071-0.012^length=<55.5^cyclist_bmi=22.2-22.84]
# grew rule: [previous_mean_position=0.33-0.38^race_season%summer=0^previous_mean_cp=0.0071-0.012^length=<55.5^cyclist_bmi=22.2-22.84]
#
# rule 6 of 10
# original: [previous_mean_position=0.33-0.38]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.38-0.42^cyclist_age_group=1^race_season%summer=0^cyclist_previous_experience=0.24-0.31^race_physical_effort=0.29-0.4]
# grew rule: [previous_mean_position=0.38-0.42^cyclist_age_group=1^race_season%summer=0^cyclist_previous_experience=0.24-0.31^race_physical_effort=0.29-0.4]
#
# rule 7 of 10
# original: [previous_mean_position=0.38-0.42]
# replacement: unchanged
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.42-0.46^race_season%summer=0^cyclist_age_group=1^race_season%spring=1^cyclist_bmi=<19.47^race_prestige=0.097-0.11^previous_mean_cp=0.0032-0.004]
# grew rule: [previous_mean_position=0.28-0.33^race_physical_effort=0.29-0.4^previous_mean_cp=0.0071-0.012^race_season%summer=0]
#
# rule 8 of 10
# original: [previous_mean_position=0.28-0.33^race_physical_effort=0.29-0.4^previous_mean_cp=0.0071-0.012^race_season%summer=0]
# replacement: [previous_mean_position=0.42-0.46^race_season%summer=0]
# revision: [previous_mean_position=0.28-0.33]
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.42-0.46^race_season%summer=0^length=>226.5^race_season%autumn=1^previous_mean_cp=0.0021-0.0026]
# grew rule: [previous_mean_position=0.42-0.46^cyclist_age_group=0^race_season%summer=0^length=188.0-197.5^race_season%winter=0]
#
# rule 9 of 10
# original: [previous_mean_position=0.42-0.46^cyclist_age_group=0]
# replacement: [previous_mean_position=0.42-0.46^race_season%summer=0]
# revision: unchanged
# *best: unchanged
# best already included in optimization -- retaining original
#
# grew rule: [previous_mean_position=0.46-0.5^cyclist_bmi=>22.84^climb_percentage=<0.0054^previous_mean_delta=482.0-549.07^race_season%winter=0]
# grew rule: [previous_mean_position=<0.28^race_physical_effort=0.14-0.2^previous_mean_cp=0.0071-0.012^race_season%winter=0^cyclist_previous_experience=0.48-0.63]
#
# rule 10 of 10
# original: [previous_mean_position=<0.28^race_physical_effort=0.14-0.2^previous_mean_cp=0.0071-0.012^race_season%winter=0^cyclist_previous_experience=0.48-0.63]
# replacement: [previous_mean_position=0.46-0.5^cyclist_bmi=>22.84]
# revision: [previous_mean_position=<0.28]
# *best: [previous_mean_position=0.46-0.5^cyclist_bmi=>22.84]
#
#
# OPTIMIZED RULESET:
# iteration 5 of 5
#  modified rules [9]
# [[previous_mean_position=<0.28] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.29-0.4 ^ previous_mean_delta=<161.11] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.2-0.29 ^ previous_mean_delta=<161.11 ^ cyclist_previous_experience=>0.63] V
# [previous_mean_position=0.28-0.33] V
# [previous_mean_position=0.33-0.38] V
# [previous_mean_position=0.38-0.42] V
# [previous_mean_position=0.28-0.33 ^ race_physical_effort=0.29-0.4 ^ previous_mean_cp=0.0071-0.012 ^ race_season%summer=0] V
# [previous_mean_position=0.42-0.46 ^ cyclist_age_group=0] V
# [previous_mean_position=0.46-0.5 ^ cyclist_bmi=>22.84]]
#
# 40942 pos left. Growing final rules...
# growing ruleset...
# initial model: [[previous_mean_position=<0.28] V [previous_mean_position=<0.28^race_physical_effort=>0.4] V [previous_mean_position=<0.28^race_physical_effort=0.29-0.4^previous_mean_delta=<161.11] V [previous_mean_position=<0.28^race_physical_effort=0.2-0.29^previous_mean_delta=<161.11^cyclist_previous_experience=>0.63] V [previous_mean_position=0.28-0.33] V [previous_mean_position=0.33-0.38] V [previous_mean_position=0.38-0.42] V [previous_mean_position=0.28-0.33^race_physical_effort=0.29-0.4^previous_mean_cp=0.0071-0.012^race_season%summer=0] V [previous_mean_position=0.42-0.46^cyclist_age_group=0] V [previous_mean_position=0.46-0.5^cyclist_bmi=>22.84]]
#
# GREW FINAL RULES
# [[previous_mean_position=<0.28] V
# [previous_mean_position=<0.28 ^ race_physical_effort=>0.4] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.29-0.4 ^ previous_mean_delta=<161.11] V
# [previous_mean_position=<0.28 ^ race_physical_effort=0.2-0.29 ^ previous_mean_delta=<161.11 ^ cyclist_previous_experience=>0.63] V
# [previous_mean_position=0.28-0.33] V
# [previous_mean_position=0.33-0.38] V
# [previous_mean_position=0.38-0.42] V
# [previous_mean_position=0.28-0.33 ^ race_physical_effort=0.29-0.4 ^ previous_mean_cp=0.0071-0.012 ^ race_season%summer=0] V
# [previous_mean_position=0.42-0.46 ^ cyclist_age_group=0] V
# [previous_mean_position=0.46-0.5 ^ cyclist_bmi=>22.84]]
#
# Optimizing dl...
# FINAL RULESET:
# [[previous_mean_position=<0.28] V
# [previous_mean_position=0.28-0.33] V
# [previous_mean_position=0.33-0.38] V
# [previous_mean_position=0.38-0.42] V
# [previous_mean_position=0.42-0.46 ^ cyclist_age_group=0] V
# [previous_mean_position=0.46-0.5 ^ cyclist_bmi=>22.84]]
#
# rule 0 [previous_mean_position=<0.28]
# n_samples: 81884 tp: 6360 fp: 1562 tpr: 0.8028275687957587 fpr: 0.19717243120424136 class_ns: (1562, 6360) class_freqs: (0.19717243120424136, 0.8028275687957587) smoothed_class_freqs: [0.19724886420999496, 0.802751135790005]
# rule 1 [previous_mean_position=0.28-0.33]
# n_samples: 81884 tp: 5797 fp: 2290 tpr: 0.716829479411401 fpr: 0.283170520588599 class_ns: (2290, 5797) class_freqs: (0.283170520588599, 0.716829479411401) smoothed_class_freqs: [0.2832241315366547, 0.7167758684633453]
# rule 2 [previous_mean_position=0.33-0.38]
# n_samples: 81884 tp: 5680 fp: 3061 tpr: 0.6498112344125386 fpr: 0.35018876558746137 class_ns: (3061, 5680) class_freqs: (0.35018876558746137, 0.6498112344125386) smoothed_class_freqs: [0.3502230355713142, 0.6497769644286858]
# rule 3 [previous_mean_position=0.38-0.42]
# n_samples: 81884 tp: 4313 fp: 3296 tpr: 0.5668287554212117 fpr: 0.43317124457878825 class_ns: (3296, 4313) class_freqs: (0.43317124457878825, 0.5668287554212117) smoothed_class_freqs: [0.43318880567599527, 0.5668111943240047]
# rule 4 [previous_mean_position=0.42-0.46^cyclist_age_group=0]
# n_samples: 81884 tp: 841 fp: 666 tpr: 0.5580623755806238 fpr: 0.44193762441937623 class_ns: (666, 841) class_freqs: (0.44193762441937623, 0.5580623755806238) smoothed_class_freqs: [0.44201457919151754, 0.5579854208084825]
# rule 5 [previous_mean_position=0.46-0.5^cyclist_bmi=>22.84]
# n_samples: 81884 tp: 910 fp: 568 tpr: 0.6156968876860622 fpr: 0.38430311231393777 class_ns: (568, 910) class_freqs: (0.38430311231393777, 0.6156968876860622) smoothed_class_freqs: [0.3844594594594595, 0.6155405405405405]
# tn: 29499 fn: 17041 tnr: 0.6338418564675548 fnr: 0.3661581435324452 ruleset_uncovered_class_ns: (29499, 17041) ruleset_uncovered_class_freqs (0.6338418564675548, 0.3661581435324452) smoothed_uncovered_class_freqs_ [0.6338361050234197, 0.3661638949765803]

# %%
df = pd.DataFrame(rand_search.cv_results_)
df.sort_values(by='rank_test_f1_macro', inplace=True)
df.to_csv(f'../../data/ml_datasets/undersampling/model_selection/{USER}_rule_based_results.csv', index=False)
